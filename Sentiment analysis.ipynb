# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
text=open(r"C:\Users\deept\ML\txt_reviews\review_1.txt")
text.read()
# Out:
# 'ProductId: B001E4KFG0\nUserId: A3SGXH7AUHU8GW\nProfileName: delmartian\nHelpfulnessNumerator: 1\nHelpfulnessDenominator: 1\nScore: 5\nTime: 1303862400\nReviewSummary: Good Quality Dog Food\nReviewText: I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.\n'

# %%
ProductId = []
UserId = []
ProfileName = []
HelpfulnessNumerator = []
HelpfulnessDenominator = []
Score = []
Time = []
ReviewSummary = []
ReviewText = []

for i in range(1,568455):
    text = open(fr"C:\Users\deept\ML\txt_reviews\review_{i}.txt")
    ls = text.read()
    splt_ls = ls.split("\n")[0]
    ProductId.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[1]
    UserId.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[2]
    ProfileName.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[3]
    HelpfulnessNumerator.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[4]
    HelpfulnessDenominator.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[5]
    Score.append(splt_ls.split(":")[1])
    splt_ls = ls.split("\n")[6]
    Time.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[7]
    ReviewSummary.append(splt_ls.split(":")[1])

    splt_ls = ls.split("\n")[8]
    ReviewText.append(splt_ls.split(":")[1])

# %%
dict1={"ProductId":ProductId,"UserId":UserId,"ProfileName":ProfileName,"HelpfulnessNumerator":HelpfulnessNumerator,"HelpfulnessDenominator":HelpfulnessDenominator,"Score":Score,"Time":Time,"ReviewSummary":ReviewSummary,"ReviewText":ReviewText}

# %%
df=pd.DataFrame(dict1)

# %%
df

# %%
df.to_csv("User.csv")

# %%
Data=pd.read_csv("User.csv")

# %%
Data
# Out:
#         Unnamed: 0    ProductId           UserId  \
# 0                0   B001E4KFG0   A3SGXH7AUHU8GW
# 1                1   B00813GRG4   A1D87F6ZCVE5NK
# 2                2   B000LQOCH0    ABXLMWJIXXAIN
# 3                3   B000UA0QIQ   A395BORC6FGVXV
# 4                4   B006K2ZZ7K   A1UQRSCLF8GW1T
# ...            ...          ...              ...
# 568449      568449   B001EO7N10   A28KG5XORO54AY
# 568450      568450   B003S1WTCU   A3I8AFVPEE8KI5
# 568451      568451   B004I613EE   A121AA1GQV751Z
# 568452      568452   B004I613EE    A3IBEVCTXKNOH
# 568453      568453   B001LR2CU2   A3LGQPJCZVL9UC
#
#                              ProfileName  HelpfulnessNumerator  \
# 0                             delmartian                     1
# 1                                 dll pa                     0
# 2        Natalia Corres "Natalia Corres"                     1
# 3                                   Karl                     3
# ...

# %%
Data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
Data.columns
# Out:
# Index(['ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'ReviewSummary',
#        'ReviewText'],
#       dtype='object')

# %%
Data.isnull().sum()
# Out:
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# ReviewSummary             0
# ReviewText                0
# dtype: int64

# %%
Data.duplicated(keep="first").sum()
# Out:
# 287

# %%
Data.drop_duplicates(keep="first",inplace=True)
Data.duplicated(keep="first").sum()
# Out:
# 0

# %%
Data["Helpfullness"]=Data["HelpfulnessNumerator"]/Data["HelpfulnessDenominator"]

# %%
Data["Helpfullness"]
# Out:
# 0         1.0
# 1         NaN
# 2         1.0
# 3         1.0
# 4         NaN
#          ...
# 568449    NaN
# 568450    NaN
# 568451    1.0
# 568452    1.0
# 568453    NaN
# Name: Helpfullness, Length: 568167, dtype: float64

# %%
# Data["Review"]=pd.concat(Data[["ReviewSummary"]],Data[["ReviewText"]])
Data["Review"] = Data['ReviewSummary'].astype(str) +" "+ Data["ReviewText"]
print(Data["Review"])
# Out:
# 0          Good Quality Dog Food  I have bought several ...
# 1          Not as Advertised  Product arrived labeled as...
# 2          "Delight" says it all  This is a confection t...
# 3          Cough Medicine  If you are looking for the se...
# 4          Great taffy  Great taffy at a great price.  T...
#                                 ...
# 568449     Will not do without  Great for sesame chicken...
# 568450     disappointed  I'm disappointed with the flavo...
# 568451     Perfect for our maltipoo  These stars are sma...
# 568452     Favorite Training and reward treat  These are...
# 568453     Great Honey  I am very satisfied ,product is ...
# Name: Review, Length: 568167, dtype: object

# %%
Data
# Out:
#           ProductId           UserId                       ProfileName  \
# 0        B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1        B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2        B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3        B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4        B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
# ...             ...              ...                               ...
# 568449   B001EO7N10   A28KG5XORO54AY                  Lettie D. Carter
# 568450   B003S1WTCU   A3I8AFVPEE8KI5                         R. Sawyer
# 568451   B004I613EE   A121AA1GQV751Z                     pksd "pk_007"
# 568452   B004I613EE    A3IBEVCTXKNOH           Kathy A. Welch "katwel"
# 568453   B001LR2CU2   A3LGQPJCZVL9UC                          srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
Data.isnull().sum()
# Out:
# ProductId                      0
# UserId                         0
# ProfileName                    0
# HelpfulnessNumerator           0
# HelpfulnessDenominator         0
# Score                          0
# Time                           0
# ReviewSummary                  0
# ReviewText                     0
# Helpfullness              269844
# Review                         0
# dtype: int64

# %%
Data["Helpfullness"]=Data["Helpfullness"].fillna(0)

# %%
Data.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %%
Data.dtypes
# Out:
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator        int64
# HelpfulnessDenominator      int64
# Score                       int64
# Time                        int64
# ReviewSummary              object
# ReviewText                 object
# Helpfullness              float64
# Review                     object
# dtype: object

# %%
Score= { 1:"Very poor", 2:"Poor", 3:"Average",4:"Good", 5:"Very Good"}

Data["Score"]= Data["Score"].apply(lambda x : Score[x])

# %%
Data["Score"].value_counts()
# Out:
# 5    362930
# 4     80627
# 1     52231
# 3     42614
# 2     29765
# Name: Score, dtype: int64

# %%
size = (8,4)
fig, ax = plt.subplots(figsize=size)
plt.title('Score')
sns.countplot(data=Data, x=Data["Score"])
plt.show()

# %%
Data["Score"].value_counts().
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17240\3354411416.py in <module>
# ----> 1 Data["Score"].value_counts().countplot()
#
# C:\Users\ deept\OneDrive\Desktop\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'countplot'

# %%
Data.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator      Score        Time  \
# 0                     1                       1  Very Good  1303862400
# 1                     0                       0  Very poor  1346976000
# 2                     1                       1       Good  1219017600
# 3                     3                       3       Poor  1307923200
# 4                     0                       0  Very Good  1350777600
#
#             ReviewSummary                                         ReviewText  \
# ...

# %%
y=Data["Score"]
X=Data[["Review"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=100)

# %%
X_train.shape
# Out:
# (426125, 1)

# %%
X_test.shape
# Out:
# (142042, 1)

# %%
y_train.shape
# Out:
# (426125,)

# %%
y_test.shape
# Out:
# (142042,)

# %%
X_train.head()
# Out:
#                                                    Review
# 40571    Recommended by herbalist--love it.  We've bee...
# 459082   Taste like Hot Wings  I can't give these a 5 ...
# 180167   good cup of joe  This is a very good coffee. ...
# 138329   Loacker Quadratini Lemon Wafer Cookie  This w...
# 111573   Great herbal tea  I grew up on lipton black t...

# %% [markdown]
# ## Data Prepration - Text Preprocessing

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('stopwords')
# Downloading wordnet before applying Lemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\deept\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\deept\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\deept\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
stemmer=PorterStemmer()

# %%
lemmatizer=WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    # Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # change sentence to lower case
    sentence = sentence.lower()

    # tokenize into words
    tokens = sentence.split()
    
    # remove stop words                
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'stem'):
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
import time

# %%
# %%time
temp_df = X_train['Review'].apply(lambda x : preprocess(x, 'lemma'))

temp_df.head()

# %%
temp_df.isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
temp_df.columns = ['clean_text_lemma', 'text_length_lemma']

temp_df.head()
# Out:
#                                          clean_text_lemma  text_length_lemma
# 40571   recommended herbalist love drinking tea year m...                 57
# 459082  taste like hot wing give ingredient show proce...                 37
# 180167  good cup joe good coffee son enjoy coffee even...                 18
# 138329  loacker quadratini lemon wafer cookie wafer be...                 19
# 111573  great herbal tea grew lipton black tea brewed ...                 42

# %%
X_train =pd.concat([X_train,temp_df],axis=1)
X_train.head()
# Out:
#                                                    Review  \
# 40571    Recommended by herbalist--love it.  We've bee...
# 459082   Taste like Hot Wings  I can't give these a 5 ...
# 180167   good cup of joe  This is a very good coffee. ...
# 138329   Loacker Quadratini Lemon Wafer Cookie  This w...
# 111573   Great herbal tea  I grew up on lipton black t...
#
#                                          clean_text_lemma  text_length_lemma
# 40571   recommended herbalist love drinking tea year m...                 57
# 459082  taste like hot wing give ingredient show proce...                 37
# 180167  good cup joe good coffee son enjoy coffee even...                 18
# 138329  loacker quadratini lemon wafer cookie wafer be...                 19
# 111573  great herbal tea grew lipton black tea brewed ...                 42

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(temp_df['clean_text_lemma'])

# %%
X_train_bow
# Out:
# <426125x85947 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13342481 stored elements in Compressed Sparse Row format>

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words: 85947
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (426125, 85947)

# %%
#Creating world cloud

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from wordcloud import WordCloud

# %%
y_train
# Out:
# 40571     Very Good
# 459082         Good
# 180167    Very Good
# 138329    Very Good
# 111573    Very Good
#             ...
# 344603    Very Good
# 213032    Very Good
# 65641          Good
# 210871    Very Good
# 56112          Good
# Name: Score, Length: 426125, dtype: object

# %%
four_df=X_train.loc[y_train=="Good",:]

# %%
four_df.head()
# Out:
#                                                    Review  \
# 459082   Taste like Hot Wings  I can't give these a 5 ...
# 127439   Capitalizing on the Marley Legend-Organic Fai...
# 188828   Calm  Product was as promised. I found that i...
# 348946   Snapea are not snappy but good enough  The cr...
# 475991   Very pleasant oil  I bought this oil to use o...
#
#                                          clean_text_lemma  text_length_lemma
# 459082  taste like hot wing give ingredient show proce...                 37
# 127439  capitalizing marley legend organic fair trade ...                 93
# 188828  calm product promised found lessened cramping ...                 11
# 348946  snapea snappy good enough crips pea shaped cri...                 37
# 475991  pleasant oil bought oil use salad allergy supp...                 30

# %%
words = ' '.join(four_df['clean_text_lemma'])

print(words[:100])
# Out:
# taste like hot wing give ingredient show processed sure healthy br br taste great hot like nuclear z

# %%
clean_word=' '.join([word for word in words.split() if 'br' not in word])

# %%
four_wordcloud=WordCloud(stopwords=stopwords.words('english'),
                           background_color='black',
                           width=1600,
                           height=800).generate(clean_word)

# %%
plt.figure(1,figsize=(30,20))
plt.imshow(four_wordcloud)
plt.axis('off')
plt.show()

# %%
two_df=X_train.loc[y_train=="Poor",:]
two_df.head()
# Out:
#                                                    Review  \
# 134301   Pre-ground coffee is bad coffee!  If you are ...
# 184767   Twice The Price  It's a great product but why...
# 130818   NOT GOOD SOIL AT ALL!!!!WHEN  I GOT THE PLANT...
# 306015   misleading product picture  The product pictu...
# 148443   This is NOT DECAFFINATED COFFEE, Green box do...
#
#                                          clean_text_lemma  text_length_lemma
# 134301  pre ground coffee bad coffee thinking intellig...                 35
# 184767  twice price great product would buy amazon cou...                 22
# 130818  good soil got plant leaf hole ive plant month ...                 42
# 306015  misleading product picture product picture ind...                 24
# 148443  decaffinated coffee green box mean jack green ...                 47

# %%
words = ' '.join(two_df['clean_text_lemma'])

print(words[:100])
# Out:
# pre ground coffee bad coffee thinking intelligentsia label gonna get better coffee make huge differe

# %%
clean_word=' '.join([word for word in words.split() if 'br' not in word])

# %%
two_wordcloud=WordCloud(stopwords=stopwords.words('english'),
                           background_color='black',
                           width=1600,
                           height=800).generate(clean_word)

# %%
plt.figure(1,figsize=(30,20))
plt.imshow(two_wordcloud)
plt.axis('off')
plt.show()

# %%
#Model bulding

# %%
# %%time
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow, y_train)
# Out:
# Wall time: 1min 59s
# C:\Users\ deept\OneDrive\Desktop\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # X_test preprocessing

# %%
X_test.head()
# Out:
#                                                    Review
# 538562   Delicious crumb cake  Although I have been gl...
# 428501   Love me some Community Coffee!  This is my fa...
# 25186    Not Much of a Puzzle  After the first go-roun...
# 328048   My favorite cookies!  Love these cookies. Per...
# 73156    The Original  Just want to share that the fir...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142042 entries, 538562 to 217285
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Review  142042 non-null  object
# dtypes: object(1)
# memory usage: 2.2+ MB

# %%
# %%time

df_X_test = X_test['Review'].apply(lambda x : preprocess(x, 'lemma'))

df_X_test.head()
# Out:
# Wall time: 2h 7min 53s
#                                                         0   1
# 538562  delicious crumb cake although gluten free long...  88
# 428501  love community coffee favorite coffee coffee g...  33
# 25186   much puzzle first go round little mutt knew ex...  58
# 328048  favorite cooky love cooky perfect oz size bag ...  17
# 73156   original want share first reviewer giving star...  17

# %%
df_X_test .columns = ['clean_text_lemma', 'text_length_lemma']

df_X_test .head()
# Out:
#                                          clean_text_lemma  text_length_lemma
# 538562  delicious crumb cake although gluten free long...                 88
# 428501  love community coffee favorite coffee coffee g...                 33
# 25186   much puzzle first go round little mutt knew ex...                 58
# 328048  favorite cooky love cooky perfect oz size bag ...                 17
# 73156   original want share first reviewer giving star...                 17

# %%
X_test_bow = vocab.transform(df_X_test['clean_text_lemma'])

# %%
from tqdm import tqdm,tqdm_notebook

# %%
tqdm.pandas()

# %%
# Logistic regression

# %%
# %%time
y_test_pred = classifier.predict(X_test_bow)
# Out:
# Wall time: 117 ms

# %%
from sklearn.metrics import accuracy_score,classification_report

print(accuracy_score(y_test, y_test_pred))
print("class :",classification_report(y_test,y_test_pred))
# Out:
# 0.7527562270314414
# class :               precision    recall  f1-score   support
#
#      Average       0.49      0.37      0.42     10536
#         Good       0.52      0.28      0.36     20127
#         Poor       0.47      0.28      0.35      7507
#    Very Good       0.81      0.95      0.88     90810
#    Very poor       0.70      0.69      0.69     13062
#
#     accuracy                           0.75    142042
#    macro avg       0.60      0.51      0.54    142042
# weighted avg       0.72      0.75      0.73    142042

# %%
#DecisionTree

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_bow, y_train)
# Out:
# Wall time: 1h 3min 55s
# DecisionTreeClassifier()

# %%
# %%time
y_test_pred = classifier.predict(X_test_bow)
# Out:
# Wall time: 491 ms

# %%
from sklearn.metrics import accuracy_score,classification_report

print(accuracy_score(y_test, y_test_pred))
print("class :",classification_report(y_test,y_test_pred))
# Out:
# 0.7623519804001634
# class :               precision    recall  f1-score   support
#
#      Average       0.54      0.50      0.52     10536
#         Good       0.57      0.52      0.54     20127
#         Poor       0.53      0.46      0.49      7507
#    Very Good       0.85      0.89      0.87     90810
#    Very poor       0.66      0.65      0.66     13062
#
#     accuracy                           0.76    142042
#    macro avg       0.63      0.60      0.62    142042
# weighted avg       0.75      0.76      0.76    142042

# %%
#Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_bow, y_train)
# Out:
# Wall time: 3h 50min 42s
# RandomForestClassifier()

# %%
# %%time
y_test_pred = classifier.predict(X_test_bow)
# Out:
# Wall time: 1min 16s

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_test_pred))
# Out:
# 0.8013545289421439

# %%
#support vector

# %%
# %%time
from sklearn.svm  import SVC
classifier = SVC()
classifier.fit(X_train_bow,y_train)

# %%
# %%time
y_test_pred_s =classifier.predict(X_test_transform)

# %%
from sklearn.metrics import accuracy_score,classification_report
print("accuracy:",accuracy_score(y_test,y_test_pred_s))
print("class :",classification_report(y_test,y_test_pred_s))

# %%
#naive baye's

# %%
# %%time
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train_bow,y_train)
# Out:
# Wall time: 2.67 s
# MultinomialNB()

# %%
# %%time
y_test_pred_nb =nb.predict(X_test_bow)
# Out:
# Wall time: 546 ms

# %%
from sklearn.metrics import accuracy_score,classification_report
print("accuracy:",accuracy_score(y_test,y_test_pred_nb))
print("class :",classification_report(y_test,y_test_pred_nb))
# Out:
# accuracy: 0.7164430238943411
# class :               precision    recall  f1-score   support
#
#      Average       0.44      0.35      0.39     10536
#         Good       0.41      0.39      0.40     20127
#         Poor       0.43      0.26      0.32      7507
#    Very Good       0.84      0.88      0.86     90810
#    Very poor       0.58      0.67      0.63     13062
#
#     accuracy                           0.72    142042
#    macro avg       0.54      0.51      0.52    142042
# weighted avg       0.70      0.72      0.71    142042

# %%
# TFIDF

# %%
#Logistic regression

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
vector=TfidfVectorizer()
X_train_transform=vector.fit_transform(X_train['clean_text_lemma'])
# Out:
# Wall time: 35.4 s

# %%
# %%time
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(X_train_transform,y_train)
# Out:
# Wall time: 1min 40s
# C:\Users\ deept\OneDrive\Desktop\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# %%time
y_test_pred_l =reg.predict(X_test_bow)
# step 7

from sklearn.metrics import accuracy_score,classification_report
print("accuracy:",accuracy_score(y_test,y_test_pred_l))
print("class :",classification_report(y_test,y_test_pred_l))
# Out:
# accuracy: 0.7122330015065966
# class :               precision    recall  f1-score   support
#
#      Average       0.42      0.34      0.37     10536
#         Good       0.38      0.50      0.43     20127
#         Poor       0.36      0.36      0.36      7507
#    Very Good       0.86      0.86      0.86     90810
#    Very poor       0.75      0.54      0.63     13062
#
#     accuracy                           0.71    142042
#    macro avg       0.55      0.52      0.53    142042
# weighted avg       0.73      0.71      0.72    142042
#
# Wall time: 5.76 s

# %%
import pickle
filename="trained_LR_model_sentiment.sav"
pickle.dump(LG_classifier,open(filename,"wb"))
loaded_LR_model=pickle.load(open("trained_LR_model_sentiment.sav","rb"))
vectorizer_filename="CountVectorizer.sav"
pickle.dump(vocab,open(vectorizer_filename,"wb"))
loaded_vectorizer=pickle.load(open("CountVectorizer.sav","rb"))
 
# Text input for prediction


# Preprocess the text input (cleaning, tokenization, etc., if needed)
preprocessed_text =["very good"]

# Vectorize the preprocessed text using the loaded TF-IDF vectorizer
text_vector = loaded_vectorizer.transform(preprocessed_text)

# Make predictions using the loaded model
sentiment_prediction = loaded_LR_model.predict(text_vector)

print(sentiment_prediction)

# %%
a='12'
i=a.isdigit()
i
# Out:
# True

# %%
l=[1,"a",2]
for i in l:
    if i in i.isdigit():
        print(i)
#     x=i.isdigit()
#     print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17712\3597598640.py in <module>
#       1 l=[1,"a",2]
#       2 for i in l:
# ----> 3     if i in i.isdigit():
#       4         print(i)
#       5 #     x=i.isdigit()
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
list(filter(lambda n: isinstance(n, int), [1,2,"three"]))
# Out:
# [1, 2]
